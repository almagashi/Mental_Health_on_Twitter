# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn import linear_model, metrics
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %% [markdown]
# **Data Description**

# %%
sent = pd.read_csv('liwcocd.csv')
sent.head()
# Out:
#    Source (A)           Source (B)  Source (C)       Source (D)  \
# 0           0   829318199468490752         294      Eora Nation
# 1           1            415086641         432           London
# 2           2  1311981838026657792          17              NaN
# 3           3             89962967       29198  Boulder CO, USA
# 4           4   885311783795212288         981             Hell
#
#                                           Source (E)           Source (F)  \
# 0  PhD candidate in gender and cultural studies @...  2021-10-27 11:59:28
# 1  Children’s Book Illustrator 🎨 & former @pathwa...  2021-10-27 11:51:28
# 2  One of the greatest regrets in life is being w...  2021-10-27 11:26:01
# 3  Peter Strong - Psychotherapist specializing in...  2021-10-27 11:25:00
# 4  A free thinker and freelance writer\r\r\n\r\r\...  2021-10-27 11:06:55
#
#                                           Source (G)       Source (H)  WC  \
# 0  New research out finds that #acupuncture reduc...              NaN  45
# 1  New research out finds that #acupuncture reduc...          ['ocd']  45
# 2  New research out finds that #acupuncture reduc...  ['oknottobeok']  45
# 3  New research out finds that #acupuncture reduc...          ['OCD']  45
# 4  New research out finds that #acupuncture reduc...              NaN  45
#
#    Analytic   ...    risk  focuspast  focuspresent  focusfuture  informal  \
# 0     46.37   ...     0.0       4.44          6.67          0.0      4.44
# 1     46.37   ...     0.0       4.44          6.67          0.0      4.44
# 2     46.37   ...     0.0       4.44          6.67          0.0      4.44
# 3     46.37   ...     0.0       4.44          6.67          0.0      4.44
# 4     46.37   ...     0.0       4.44          6.67          0.0      4.44
#
#    swear  netspeak  assent  nonflu  filler
# 0    0.0      4.44     0.0     0.0     0.0
# 1    0.0      4.44     0.0     0.0     0.0
# 2    0.0      4.44     0.0     0.0     0.0
# 3    0.0      4.44     0.0     0.0     0.0
# 4    0.0      4.44     0.0     0.0     0.0
#
# [5 rows x 49 columns]

# %%
sent.columns
# Out:
# Index(['Source (A)', 'Source (B)', 'Source (C)', 'Source (D)', 'Source (E)',
#        'Source (F)', 'Source (G)', 'Source (H)', 'WC', 'Analytic', 'Clout',
#        'Authentic', 'Tone', 'WPS', 'Sixltr', 'Dic', 'affect', 'posemo',
#        'negemo', 'anx', 'anger', 'sad', 'social', 'family', 'friend', 'female',
#        'male', 'cogproc', 'insight', 'cause', 'discrep', 'tentat', 'certain',
#        'differ', 'drives', 'affiliation', 'achieve', 'power', 'reward', 'risk',
#        'focuspast', 'focuspresent', 'focusfuture', 'informal', 'swear',
#        'netspeak', 'assent', 'nonflu', 'filler'],
#       dtype='object')

# %%
posemo = sent['posemo']
negemo = sent['negemo']
tone = sent['Tone']

print(np.mean(posemo))
print(np.mean(negemo))
print(np.mean(tone))
# Out:
# 2.6491198044009883
# 3.3707998602864064
# 36.44690534404496
