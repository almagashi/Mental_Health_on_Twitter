# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn import linear_model, metrics
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
import statsmodels.api as sm
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %% [markdown]
# **Data Description**

# %%
# Out:
#    A                    B     C                        D  \
# 0  0  1365319367676878849    52       Sheffield, England
# 1  1             53638786  1667                       UK
# 2  2  1329360990765539329    12  England, United Kingdom
# 3  3  1242603133450293261     8       West Hempstead, NY
# 4  4  1429032961744281602    48                   España
#
#                                                    E                    F  \
# 0  ❤Sal / UK\r\r\n🧡Player of games, Master of non...  2021-10-27 12:40:38
# 1  27y/o nonbinary creator. They/Them. disabled. ...  2021-10-27 12:40:00
# 2  38. A diagnosis referral is hard in the UK. Se...  2021-10-27 12:37:21
# 3  OrganizeU4Life is making an impact on the live...  2021-10-27 12:35:03
# 4  🔞. Mainly NSFW. He/Him. 28. Gay, Single and Lo...  2021-10-27 12:33:08
#
#                                                    G                    H  WC  \
# 0  Saw GP today and we went through stuff and I t...                  NaN  47
# 1  My ADHD Graveyard | Officially Diagnosed and A...                  NaN  33
# 2  Have there been any studies of adults or child...  ['askADHD', 'ADHD']  21
# 3  Environmental factors don’t directly cause ADH...                  NaN  42
# 4  Here in Spain we celebrate the national day of...             ['ADHD']  35
#
#    Analytic   ...    risk  focuspast  focuspresent  focusfuture  informal  \
# 0     81.28   ...    0.00       4.26         10.64         0.00      0.00
# 1     73.59   ...    0.00       0.00          3.03         0.00      6.06
# 2     87.62   ...    0.00       4.76          4.76         0.00      0.00
# 3     68.29   ...    0.00       0.00          4.76         0.00      4.76
# 4     86.18   ...    2.86       0.00          2.86         2.86      2.86
#
#    swear  netspeak  assent  nonflu  filler
# 0    0.0      0.00     0.0     0.0     0.0
# 1    0.0      6.06     0.0     0.0     0.0
# 2    0.0      0.00     0.0     0.0     0.0
# 3    0.0      4.76     0.0     0.0     0.0
# 4    0.0      2.86     0.0     0.0     0.0
#
# [5 rows x 49 columns]

# %%
sent.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'WC', 'Analytic', 'Clout',
#        'Authentic', 'Tone', 'WPS', 'Sixltr', 'Dic', 'affect', 'posemo',
#        'negemo', 'anx', 'anger', 'sad', 'social', 'family', 'friend', 'female',
#        'male', 'cogproc', 'insight', 'cause', 'discrep', 'tentat', 'certain',
#        'differ', 'drives', 'affiliation', 'achieve', 'power', 'reward', 'risk',
#        'focuspast', 'focuspresent', 'focusfuture', 'informal', 'swear',
#        'netspeak', 'assent', 'nonflu', 'filler'],
#       dtype='object')

# %%
posemo = sent['posemo']
negemo = sent['negemo']
tone = sent['Tone']

print(np.mean(posemo))
print(np.mean(negemo))
print(np.mean(tone))
# Out:
# 1.5461720051842187
# 0.8152036659877753
# 40.86207276431081
